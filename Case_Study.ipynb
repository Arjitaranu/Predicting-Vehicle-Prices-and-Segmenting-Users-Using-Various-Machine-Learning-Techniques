# %% [markdown]
# # Case Study: Vehicle Advertisements Analysis

# %% [markdown]
# Section 1: Price Prediction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\ranu1\Downloads\vehicles.csv')
#pd.set_option('display.max_rows',None)
#pd.set_option('display.max_columns',None)

# %%
df.head(3)
# Out:
#                                          ad_title  \
# 0  Nissan Tiida Alternator  in Maharagama | ikman
# 1           Axio 165 Tail Light  in Kotte | ikman
# 2  Axio 165 / 161 Head light  in Kotte | ikman.lk
#
#                                       ad_description details  \
# 0  **TISSA AUTO PARTS** Dealer of used Japanese m...     NaN
# 1  Imported from Japan \n\nRight side available \...     NaN
# 2  Imported from Japan \n\nAuto focus headlight a...     NaN
#
#                                          slug                      title  \
# 0  nissan-tiida-alternator-for-sale-colombo-3    Nissan Tiida Alternator
# 1     axio-165-tail-light-for-sale-colombo-14        Axio 165 Tail Light
# 2    axio-165-161-head-light-for-sale-colombo  Axio 165 / 161 Head light
#
#        type      price        timestamp                posted_date  \
# 0  for_sale  Rs 18,000  23 Feb 11:35 pm  2023-02-23T23:35:10+05:30
# 1  for_sale  Rs 67,000   23 Feb 8:32 am  2023-02-23T08:32:44+05:30
# 2  for_sale  Rs 85,000   01 Dec 8:27 pm  2022-12-01T20:27:49+05:30
#
#           deactivation_date  ... is_doorstep_delivery is_dsd_applicable  \
# 0  2022-05-30T17:13:04.000Z  ...                False             False
# 1  2022-03-31T16:27:59.000Z  ...                False             False
# 2  2022-03-31T14:03:57.000Z  ...                False             False
#
#   is_member is_authorized_dealer is_featured_member  is_verified  \
# 0      True                False              False         True
# 1      True                False              False         True
# 2      True                False              False         True
#
#    membership_level    member_since  \
# 0           premium  September 2019
# 1              plus       June 2018
# 2              plus       June 2018
#
#                                           properties  \
# 0  {'Condition': 'Reconditioned', 'Part or Access...
# 1  {'Condition': 'Reconditioned', 'Part or Access...
# 2  {'Condition': 'Reconditioned', 'Part or Access...
#
#                                                 user
# 0  a6681dea494390daa516a6d2bdcb36e08c318574a13413...
# 1  5d99b8e45a1bb318079da7a36392d9025e1644cb49ecbf...
# 2  5d99b8e45a1bb318079da7a36392d9025e1644cb49ecbf...
#
# [3 rows x 26 columns]

# %%
df.isnull().sum()
# Out:
# ad_title                     0
# ad_description               7
# details                 103383
# slug                         0
# title                        0
# type                         0
# price                     3811
# timestamp                    6
# posted_date                  6
# deactivation_date            6
# category                     0
# parent_category              0
# location                     0
# geo_region                   0
# area                         0
# is_delivery_free             0
# is_doorstep_delivery         0
# is_dsd_applicable            0
# is_member                 9050
# is_authorized_dealer      9050
# is_featured_member        9050
# is_verified                  0
# membership_level             0
# member_since            150254
# properties                   0
# user                         0
# dtype: int64

# %% [markdown]
# ## Dropping the columns that can't be imputed

# %%
df.columns
# Out:
# Index(['ad_title', 'ad_description', 'details', 'slug', 'title', 'type',
#        'price', 'timestamp', 'posted_date', 'deactivation_date', 'category',
#        'parent_category', 'location', 'geo_region', 'area', 'is_delivery_free',
#        'is_doorstep_delivery', 'is_dsd_applicable', 'is_member',
#        'is_authorized_dealer', 'is_featured_member', 'is_verified',
#        'membership_level', 'member_since', 'properties', 'user'],
#       dtype='object')

# %%
df = df.drop(['ad_title', 'ad_description', 'details','slug','title'],axis=1)

# %%
df.isnull().sum()
# Out:
# type                         0
# price                     3811
# timestamp                    6
# posted_date                  6
# deactivation_date            6
# category                     0
# parent_category              0
# location                     0
# geo_region                   0
# area                         0
# is_delivery_free             0
# is_doorstep_delivery         0
# is_dsd_applicable            0
# is_member                 9050
# is_authorized_dealer      9050
# is_featured_member        9050
# is_verified                  0
# membership_level             0
# member_since            150254
# properties                   0
# user                         0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
imp1 = SimpleImputer(strategy = 'most_frequent')
df[['member_since']] = imp1.fit_transform(df[['member_since']])
df[['is_member']] = imp1.fit_transform(df[['is_member']])
df[['is_authorized_dealer']] = imp1.fit_transform(df[['is_authorized_dealer']])
df[['is_featured_member']] = imp1.fit_transform(df[['is_featured_member']])

# %%
df.isnull().sum()
# Out:
# type                       0
# price                   3811
# timestamp                  6
# posted_date                6
# deactivation_date          6
# category                   0
# parent_category            0
# location                   0
# geo_region                 0
# area                       0
# is_delivery_free           0
# is_doorstep_delivery       0
# is_dsd_applicable          0
# is_member                  0
# is_authorized_dealer       0
# is_featured_member         0
# is_verified                0
# membership_level           0
# member_since               0
# properties                 0
# user                       0
# dtype: int64

# %%
df.dropna(subset=['timestamp','posted_date','deactivation_date'], inplace = True)

# %%
df.isnull().sum()
# Out:
# type                       0
# price                   3811
# timestamp                  0
# posted_date                0
# deactivation_date          0
# category                   0
# parent_category            0
# location                   0
# geo_region                 0
# area                       0
# is_delivery_free           0
# is_doorstep_delivery       0
# is_dsd_applicable          0
# is_member                  0
# is_authorized_dealer       0
# is_featured_member         0
# is_verified                0
# membership_level           0
# member_since               0
# properties                 0
# user                       0
# dtype: int64

# %%
df['price'] = df['price'].astype(str)
df = df[df['price']!='Negotiable']
df['price'] = df['price'].apply(lambda x: x.replace('Rs ',''))
df['price'] = df['price'].apply(lambda x:x.replace(',',''))
df['price'] = pd.to_numeric(df['price'],errors='coerce')

# %%
from sklearn.impute import SimpleImputer
imp2 = SimpleImputer(strategy = 'median')
df[['price']] = imp1.fit_transform(df[['price']])

# %%
df.isnull().sum()
# Out:
# type                    0
# price                   0
# timestamp               0
# posted_date             0
# deactivation_date       0
# category                0
# parent_category         0
# location                0
# geo_region              0
# area                    0
# is_delivery_free        0
# is_doorstep_delivery    0
# is_dsd_applicable       0
# is_member               0
# is_authorized_dealer    0
# is_featured_member      0
# is_verified             0
# membership_level        0
# member_since            0
# properties              0
# user                    0
# dtype: int64

# %%
dict_df = df['properties'].apply(pd.Series)

# %%
import ast 
dict_df.iloc[0][0]    #check whether first row and column is fetching or not
dict_converted = ast.literal_eval(dict_df.iloc[0][0])   # converting python literal(dict,tuple) into python object
print(dict_converted)
# Out:
# {'Condition': 'Reconditioned', 'Part or Accessory Type': 'Electrical Components'}

# %%
dict_df.iloc[28273][0]
# Out:
# "{'Brand': 'Suzuki', 'Model': 'Wagon R FX', 'Trim / Edition': 'Safety', 'Year of Manufacture': '2017', 'Condition': 'Used', 'Transmission': 'Automatic', 'Fuel type': 'Petrol', 'Engine capacity': '660 cc', 'Mileage': '36,000 km'}"

# %%
# dict_df = df['properties'].apply(pd.Series)
# Brand = []
# Model = []
# for i in range(dict_df.shape[0]):
#     dict_converted = ast.literal_eval(dict_df.iloc[i][0])
#     if 'Brand' not in dict_converted:
#         Brand.append(np.nan)
#     else:
#         Brand.append(dict_converted['Brand'])
#     if 'Model' not in dict_converted:
#         Model.append(np.nan)
#     else:
#         Model.append(dict_converted['Model'])
# df['Brand'] = Brand
# df['Model'] = Model

# %%
Condition = []
Mileage = []
Engine_capacity = []
Fuel_type = []
Brand = []
Model = []
for i in range(dict_df.shape[0]):
    dict_converted = ast.literal_eval(dict_df.iloc[i][0])
    if 'Brand' not in dict_converted:
        Brand.append(np.nan)
    else:
        Brand.append(dict_converted['Brand'])
    if 'Model' not in dict_converted:
        Model.append(np.nan)
    else:
        Model.append(dict_converted['Model'])
    if 'Condition' not in dict_converted:
        Condition.append(np.nan)
    else:
        Condition.append(dict_converted['Condition'])

    if 'Fuel type' not in dict_converted:
        Fuel_type.append(np.nan)
    else:
        Fuel_type.append(dict_converted['Fuel type'])

    if 'Mileage' not in dict_converted:
        Mileage.append(np.nan)
    else:
        Mileage.append(dict_converted['Mileage'])

    if 'Engine capacity' not in dict_converted:
        Engine_capacity.append(np.nan)
    else:
        Engine_capacity.append(dict_converted['Engine capacity'])

df['Condition'] = Condition
df['Mileage'] = Mileage
df['Engine_capacity'] = Engine_capacity
df['Fuel_type'] = Fuel_type
df['Brand'] = Brand
df['Model'] = Model

# %%
df.dtypes
# Out:
# type                     object
# price                   float64
# timestamp                object
# posted_date              object
# deactivation_date        object
# category                 object
# parent_category          object
# location                 object
# geo_region               object
# area                     object
# is_delivery_free           bool
# is_doorstep_delivery       bool
# is_dsd_applicable          bool
# is_member                object
# is_authorized_dealer     object
# is_featured_member       object
# is_verified                bool
# membership_level         object
# member_since             object
# properties               object
# user                     object
# Condition                object
# Mileage                  object
# Engine_capacity          object
# Fuel_type                object
# Brand                    object
# Model                    object
# dtype: object

# %%
df.head(5)
# Out:
#        type    price        timestamp                posted_date  \
# 0  for_sale  18000.0  23 Feb 11:35 pm  2023-02-23T23:35:10+05:30
# 1  for_sale  67000.0   23 Feb 8:32 am  2023-02-23T08:32:44+05:30
# 2  for_sale  85000.0   01 Dec 8:27 pm  2022-12-01T20:27:49+05:30
# 3  for_sale  47000.0   04 Dec 2:47 pm  2022-12-04T14:47:27+05:30
# 4  for_sale   9000.0   08 Dec 9:28 am  2022-12-08T09:28:04+05:30
#
#           deactivation_date                  category parent_category  \
# 0  2022-05-30T17:13:04.000Z  Auto Parts & Accessories        Vehicles
# 1  2022-03-31T16:27:59.000Z  Auto Parts & Accessories        Vehicles
# 2  2022-03-31T14:03:57.000Z  Auto Parts & Accessories        Vehicles
# 3  2022-07-29T13:22:59.000Z  Auto Parts & Accessories        Vehicles
# 4  2022-07-29T12:55:44.000Z  Auto Parts & Accessories        Vehicles
#
#      location geo_region                             area  ...  \
# 0  Maharagama      LK-11  {'id': 1506, 'name': 'Colombo'}  ...
# 1       Kotte      LK-11  {'id': 1506, 'name': 'Colombo'}  ...
# 2       Kotte      LK-11  {'id': 1506, 'name': 'Colombo'}  ...
# 3     Kottawa      LK-11  {'id': 1506, 'name': 'Colombo'}  ...
# 4     Kottawa      LK-11  {'id': 1506, 'name': 'Colombo'}  ...
#
#    membership_level    member_since  \
# 0           premium  September 2019
# 1              plus       June 2018
# 2              plus       June 2018
# 3              plus   February 2017
# 4              plus   February 2017
#
#                                           properties  \
# 0  {'Condition': 'Reconditioned', 'Part or Access...
# 1  {'Condition': 'Reconditioned', 'Part or Access...
# 2  {'Condition': 'Reconditioned', 'Part or Access...
# 3  {'Condition': 'New', 'Part or Accessory Type':...
# 4  {'Condition': 'New', 'Part or Accessory Type':...
#
#                                                 user      Condition Mileage  \
# 0  a6681dea494390daa516a6d2bdcb36e08c318574a13413...  Reconditioned     NaN
# 1  5d99b8e45a1bb318079da7a36392d9025e1644cb49ecbf...  Reconditioned     NaN
# 2  5d99b8e45a1bb318079da7a36392d9025e1644cb49ecbf...  Reconditioned     NaN
# 3  634d93e14a62d9de7b400ee3679ae1d5506f4252ff0580...            New     NaN
# 4  634d93e14a62d9de7b400ee3679ae1d5506f4252ff0580...            New     NaN
#
#    Engine_capacity Fuel_type        Brand Model
# 0              NaN       NaN          NaN   NaN
# 1              NaN       NaN  Other brand   NaN
# 2              NaN       NaN          NaN   NaN
# 3              NaN       NaN          NaN   NaN
# 4              NaN       NaN          NaN   NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# #### After looking at the data we need to start transforming price into int data type,remove RS and remove ','

# %% [markdown]
# #### Finally converting to int

# %%
#df['price'] = df['price'].astype(str)
#df = df[df['price']!='Negotiable']
#df['price'] = df['price'].apply(lambda x: x.replace('Rs ',''))
#df['price'] = df['price'].apply(lambda x:x.replace(',',''))
#df['price'] = pd.to_numeric(df['price'],errors='coerce')

# %%
df['Mileage'] = df['Mileage'].astype(str)
df['Mileage'] = df['Mileage'].apply(lambda x:x.replace(' km',''))
df['Mileage'] = df['Mileage'].apply(lambda x:x.replace(',',''))
df['Mileage'] = pd.to_numeric(df['Mileage'],errors='coerce')

# %%
df['Engine_capacity'] = df['Engine_capacity'].astype(str)
df['Engine_capacity'] = df['Engine_capacity'].apply(lambda x: x.replace(' cc',''))
df['Engine_capacity'] = df['Engine_capacity'].apply(lambda x: x.replace(',',''))
df['Engine_capacity'] = pd.to_numeric(df['Engine_capacity'],errors='coerce')

# %%
df['Mileage'] = df['Mileage'].astype(float)
df['Engine_capacity'] = df['Engine_capacity'].astype(float)

# %% [markdown]
# #### Now moving onto columns where there exists categorical data of members, dealers and featured members

# %% [markdown]
# #### Looking at the data we see that the True/False values need to be encoded and then imputed wherever there's null values

# %% [markdown]
# #### Now moving to encode all categorical data

# %%
#from sklearn.preprocessing import OneHotEncoder
#from sklearn.compose import ColumnTransformer

# %%
df.head()
# Out:
#        type    price        timestamp                posted_date  \
# 0  for_sale  18000.0  23 Feb 11:35 pm  2023-02-23T23:35:10+05:30
# 1  for_sale  67000.0   23 Feb 8:32 am  2023-02-23T08:32:44+05:30
# 2  for_sale  85000.0   01 Dec 8:27 pm  2022-12-01T20:27:49+05:30
# 3  for_sale  47000.0   04 Dec 2:47 pm  2022-12-04T14:47:27+05:30
# 4  for_sale   9000.0   08 Dec 9:28 am  2022-12-08T09:28:04+05:30
#
#           deactivation_date                  category parent_category  \
# 0  2022-05-30T17:13:04.000Z  Auto Parts & Accessories        Vehicles
# 1  2022-03-31T16:27:59.000Z  Auto Parts & Accessories        Vehicles
# 2  2022-03-31T14:03:57.000Z  Auto Parts & Accessories        Vehicles
# 3  2022-07-29T13:22:59.000Z  Auto Parts & Accessories        Vehicles
# 4  2022-07-29T12:55:44.000Z  Auto Parts & Accessories        Vehicles
#
#      location geo_region                             area  ...  \
# 0  Maharagama      LK-11  {'id': 1506, 'name': 'Colombo'}  ...
# 1       Kotte      LK-11  {'id': 1506, 'name': 'Colombo'}  ...
# 2       Kotte      LK-11  {'id': 1506, 'name': 'Colombo'}  ...
# 3     Kottawa      LK-11  {'id': 1506, 'name': 'Colombo'}  ...
# 4     Kottawa      LK-11  {'id': 1506, 'name': 'Colombo'}  ...
#
#    membership_level    member_since  \
# 0           premium  September 2019
# 1              plus       June 2018
# 2              plus       June 2018
# 3              plus   February 2017
# 4              plus   February 2017
#
#                                           properties  \
# 0  {'Condition': 'Reconditioned', 'Part or Access...
# 1  {'Condition': 'Reconditioned', 'Part or Access...
# 2  {'Condition': 'Reconditioned', 'Part or Access...
# 3  {'Condition': 'New', 'Part or Accessory Type':...
# 4  {'Condition': 'New', 'Part or Accessory Type':...
#
#                                                 user      Condition Mileage  \
# 0  a6681dea494390daa516a6d2bdcb36e08c318574a13413...  Reconditioned     NaN
# 1  5d99b8e45a1bb318079da7a36392d9025e1644cb49ecbf...  Reconditioned     NaN
# 2  5d99b8e45a1bb318079da7a36392d9025e1644cb49ecbf...  Reconditioned     NaN
# 3  634d93e14a62d9de7b400ee3679ae1d5506f4252ff0580...            New     NaN
# 4  634d93e14a62d9de7b400ee3679ae1d5506f4252ff0580...            New     NaN
#
#    Engine_capacity Fuel_type        Brand Model
# 0              NaN       NaN          NaN   NaN
# 1              NaN       NaN  Other brand   NaN
# 2              NaN       NaN          NaN   NaN
# 3              NaN       NaN          NaN   NaN
# 4              NaN       NaN          NaN   NaN
#
# [5 rows x 27 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# Assume df is your DataFrame
label_encoder = LabelEncoder()

for column in df.columns:
    if df[column].dtype == 'bool' or df[column].dtype == 'object':
        df[column] = label_encoder.fit_transform(df[column])

print(df.head())
# Out:
#    type    price  timestamp  posted_date  deactivation_date  category  \
# 0     0  18000.0      85835       203003               2510         0
# 1     0  67000.0      86402       201493               1509         0
# 2     0  85000.0       1362        68293               1508         0
# 3     0  47000.0      14140        73582               3436         0
# 4     0   9000.0      31448        79694               3435         0
#
#    parent_category  location  geo_region  area  ...  membership_level  \
# 0                0       127           1     4  ...                 2
# 1                0       120           1     4  ...                 1
# 2                0       120           1     4  ...                 1
# 3                0       119           1     4  ...                 1
# 4                0       119           1     4  ...                 1
#
#    member_since  properties   user  Condition  Mileage  Engine_capacity  \
# 0            86      134982  52570          1      NaN              NaN
# 1            47      135066  29644          1      NaN              NaN
# 2            47      135074  29644          1      NaN              NaN
# 3            23      134503  31390          0      NaN              NaN
# 4            23      134503  31390          0      NaN              NaN
#
#    Fuel_type  Brand  Model
# 0          6    142    937
# 1          6     96    937
# 2          6    142    937
# 3          6    142    937
# 4          6    142    937
#
# [5 rows x 27 columns]

# %%
df.head(5)
# Out:
#    type    price  timestamp  posted_date  deactivation_date  category  \
# 0     0  18000.0      85835       203003               2510         0
# 1     0  67000.0      86402       201493               1509         0
# 2     0  85000.0       1362        68293               1508         0
# 3     0  47000.0      14140        73582               3436         0
# 4     0   9000.0      31448        79694               3435         0
#
#    parent_category  location  geo_region  area  ...  membership_level  \
# 0                0       127           1     4  ...                 2
# 1                0       120           1     4  ...                 1
# 2                0       120           1     4  ...                 1
# 3                0       119           1     4  ...                 1
# 4                0       119           1     4  ...                 1
#
#    member_since  properties   user  Condition  Mileage  Engine_capacity  \
# 0            86      134982  52570          1      NaN              NaN
# 1            47      135066  29644          1      NaN              NaN
# 2            47      135074  29644          1      NaN              NaN
# 3            23      134503  31390          0      NaN              NaN
# 4            23      134503  31390          0      NaN              NaN
#
#    Fuel_type  Brand  Model
# 0          6    142    937
# 1          6     96    937
# 2          6    142    937
# 3          6    142    937
# 4          6    142    937
#
# [5 rows x 27 columns]

# %%
df.isnull().sum()
# Out:
# type                         0
# price                        0
# timestamp                    0
# posted_date                  0
# deactivation_date            0
# category                     0
# parent_category              0
# location                     0
# geo_region                   0
# area                         0
# is_delivery_free             0
# is_doorstep_delivery         0
# is_dsd_applicable            0
# is_member                    0
# is_authorized_dealer         0
# is_featured_member           0
# is_verified                  0
# membership_level             0
# member_since                 0
# properties                   0
# user                         0
# Condition                    0
# Mileage                 101721
# Engine_capacity         101721
# Fuel_type                    0
# Brand                        0
# Model                        0
# dtype: int64

# %%
df.dtypes
# Out:
# type                      int32
# price                   float64
# timestamp                 int32
# posted_date               int32
# deactivation_date         int32
# category                  int32
# parent_category           int32
# location                  int32
# geo_region                int32
# area                      int32
# is_delivery_free          int64
# is_doorstep_delivery      int64
# is_dsd_applicable         int64
# is_member                 int32
# is_authorized_dealer      int32
# is_featured_member        int32
# is_verified               int64
# membership_level          int32
# member_since              int32
# properties                int32
# user                      int32
# Condition                 int32
# Mileage                 float64
# Engine_capacity         float64
# Fuel_type                 int32
# Brand                     int32
# Model                     int32
# dtype: object

# %% [markdown]
# #### Finally dropping properties and types column

# %%
df = df.drop(['type','properties'],axis=1)     #type has all same values that's why we dropped it,properties-we made another columns of that values

# %%
df.dtypes
# Out:
# price                   float64
# timestamp                 int32
# posted_date               int32
# deactivation_date         int32
# category                  int32
# parent_category           int32
# location                  int32
# geo_region                int32
# area                      int32
# is_delivery_free          int64
# is_doorstep_delivery      int64
# is_dsd_applicable         int64
# is_member                 int32
# is_authorized_dealer      int32
# is_featured_member        int32
# is_verified               int64
# membership_level          int32
# member_since              int32
# user                      int32
# Condition                 int32
# Mileage                 float64
# Engine_capacity         float64
# Fuel_type                 int32
# Brand                     int32
# Model                     int32
# dtype: object

# %%
# df= df.drop(['is_featured_member'],axis=1) unique values are there in category that'swhy we haven't deleted
# df = df.drop(['is_authorized_dealer'],axis=1)

# %%
df.head()
# Out:
#      price  timestamp  posted_date  deactivation_date  category  \
# 0  18000.0      85835       203003               2510         0
# 1  67000.0      86402       201493               1509         0
# 2  85000.0       1362        68293               1508         0
# 3  47000.0      14140        73582               3436         0
# 4   9000.0      31448        79694               3435         0
#
#    parent_category  location  geo_region  area  is_delivery_free  ...  \
# 0                0       127           1     4                 0  ...
# 1                0       120           1     4                 0  ...
# 2                0       120           1     4                 0  ...
# 3                0       119           1     4                 0  ...
# 4                0       119           1     4                 0  ...
#
#    is_verified  membership_level  member_since   user  Condition  Mileage  \
# 0            1                 2            86  52570          1      NaN
# 1            1                 1            47  29644          1      NaN
# 2            1                 1            47  29644          1      NaN
# 3            0                 1            23  31390          0      NaN
# 4            0                 1            23  31390          0      NaN
#
#    Engine_capacity  Fuel_type  Brand  Model
# 0              NaN          6    142    937
# 1              NaN          6     96    937
# 2              NaN          6    142    937
# 3              NaN          6    142    937
# 4              NaN          6    142    937
#
# [5 rows x 25 columns]

# %%
# df['category'].unique()

# %%
# df.shape

# %%
df.columns
# Out:
# Index(['price', 'timestamp', 'posted_date', 'deactivation_date', 'category',
#        'parent_category', 'location', 'geo_region', 'area', 'is_delivery_free',
#        'is_doorstep_delivery', 'is_dsd_applicable', 'is_member',
#        'is_authorized_dealer', 'is_featured_member', 'is_verified',
#        'membership_level', 'member_since', 'user', 'Condition', 'Mileage',
#        'Engine_capacity', 'Fuel_type', 'Brand', 'Model'],
#       dtype='object')

# %%
df.head()
# Out:
#      price  timestamp  posted_date  deactivation_date  category  \
# 0  18000.0      85835       203003               2510         0
# 1  67000.0      86402       201493               1509         0
# 2  85000.0       1362        68293               1508         0
# 3  47000.0      14140        73582               3436         0
# 4   9000.0      31448        79694               3435         0
#
#    parent_category  location  geo_region  area  is_delivery_free  ...  \
# 0                0       127           1     4                 0  ...
# 1                0       120           1     4                 0  ...
# 2                0       120           1     4                 0  ...
# 3                0       119           1     4                 0  ...
# 4                0       119           1     4                 0  ...
#
#    is_verified  membership_level  member_since   user  Condition  Mileage  \
# 0            1                 2            86  52570          1      NaN
# 1            1                 1            47  29644          1      NaN
# 2            1                 1            47  29644          1      NaN
# 3            0                 1            23  31390          0      NaN
# 4            0                 1            23  31390          0      NaN
#
#    Engine_capacity  Fuel_type  Brand  Model
# 0              NaN          6    142    937
# 1              NaN          6     96    937
# 2              NaN          6    142    937
# 3              NaN          6    142    937
# 4              NaN          6    142    937
#
# [5 rows x 25 columns]

# %%
# 2. Correlation Heatmap
plt.figure(figsize=(40,20))
plt.subplot(2, 2, 2)
numeric_cols = df.select_dtypes(include=[np.number]).columns
corr = df[numeric_cols].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Correlation\xa0Heatmap')

# %%
# 3. Count Plots for Categorical Variables
plt.figure(figsize=(15,15))
plt.subplot(3, 2, 1)
sns.countplot(y='category', data=df, order=df['category'].value_counts().index)
plt.title('Count of Ads by Category')

plt.subplot(3, 2, 2)
sns.countplot(y='is_member', data=df, order=df['is_member'].value_counts().index)
plt.title('Count of Ads by Member')

plt.subplot(3, 2, 3)
sns.countplot(y='is_verified', data=df, order=df['is_verified'].value_counts().index)
plt.title('Count of Ads by Verified Users')

plt.subplot(3, 2, 4)
sns.countplot(y='membership_level', data=df, order=df['membership_level'].value_counts().index)
plt.title('Count of Ads by Membership Level')

plt.subplot(3, 2, 5)
sns.countplot(y='Condition', data=df, order=df['Condition'].value_counts().index)
plt.title('Count of Ads by Condition')

plt.tight_layout()
plt.show()

# %%
df.tail()
# Out:
#             price  timestamp  posted_date  deactivation_date  category  \
# 258883  1030000.0         59       249725             252238         5
# 258884  3550000.0     109903       249643             252161         5
# 258885    70000.0         59       249724             252236         9
# 258886  7250000.0         57       249723             252237         5
# 258887   135000.0         57       249722             252234         8
#
#         parent_category  location  geo_region  area  is_delivery_free  ...  \
# 258883                0        93           8     8                 0  ...
# 258884                0        21           1     4                 0  ...
# 258885                0        40           1     4                 0  ...
# 258886                0        28           1     4                 0  ...
# 258887                0       110          17     1                 0  ...
#
#         is_verified  membership_level  member_since   user  Condition  \
# 258883            0                 0            15  22935          2
# 258884            0                 0            15  63632          2
# 258885            0                 0            15  63011          3
# 258886            0                 2            18  39259          2
# 258887            0                 0            15  11652          2
#
#          Mileage  Engine_capacity  Fuel_type  Brand  Model
# 258883  140000.0         140000.0          5     92    553
# 258884  219000.0         219000.0          5    128    115
# 258885       NaN              NaN          6    142    937
# 258886   30000.0          30000.0          5    128    694
# 258887   88102.0          88102.0          6    124    771
#
# [5 rows x 25 columns]

# %%
df['Mileage'].isnull().sum()
# Out:
# 101721

# %%
(df['Mileage']=='NaN').shape
# Out:
# (257209,)

# %%
mile_med = df['Mileage'].median()

# %%
df['Mileage'].replace(np.nan,mile_med,inplace=True)
# Out:
# C:\Users\ranu1\AppData\Local\Temp\ipykernel_10892\1974169234.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Mileage'].replace(np.nan,mile_med,inplace=True)

# %%
median_engcap = df['Engine_capacity'].median()
df['Engine_capacity'].replace(np.nan,median_engcap,inplace=True)
# Out:
# C:\Users\ranu1\AppData\Local\Temp\ipykernel_10892\3135958008.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Engine_capacity'].replace(np.nan,median_engcap,inplace=True)

# %%
df.head()
# Out:
#      price  timestamp  posted_date  deactivation_date  category  \
# 0  18000.0      85835       203003               2510         0
# 1  67000.0      86402       201493               1509         0
# 2  85000.0       1362        68293               1508         0
# 3  47000.0      14140        73582               3436         0
# 4   9000.0      31448        79694               3435         0
#
#    parent_category  location  geo_region  area  is_delivery_free  ...  \
# 0                0       127           1     4                 0  ...
# 1                0       120           1     4                 0  ...
# 2                0       120           1     4                 0  ...
# 3                0       119           1     4                 0  ...
# 4                0       119           1     4                 0  ...
#
#    is_verified  membership_level  member_since   user  Condition  Mileage  \
# 0            1                 2            86  52570          1  56000.0
# 1            1                 1            47  29644          1  56000.0
# 2            1                 1            47  29644          1  56000.0
# 3            0                 1            23  31390          0  56000.0
# 4            0                 1            23  31390          0  56000.0
#
#    Engine_capacity  Fuel_type  Brand  Model
# 0          56000.0          6    142    937
# 1          56000.0          6     96    937
# 2          56000.0          6    142    937
# 3          56000.0          6    142    937
# 4          56000.0          6    142    937
#
# [5 rows x 25 columns]

# %%
df.isnull().sum()
# Out:
# price                   0
# timestamp               0
# posted_date             0
# deactivation_date       0
# category                0
# parent_category         0
# location                0
# geo_region              0
# area                    0
# is_delivery_free        0
# is_doorstep_delivery    0
# is_dsd_applicable       0
# is_member               0
# is_authorized_dealer    0
# is_featured_member      0
# is_verified             0
# membership_level        0
# member_since            0
# user                    0
# Condition               0
# Mileage                 0
# Engine_capacity         0
# Fuel_type               0
# Brand                   0
# Model                   0
# dtype: int64

# %%
df.head()
# Out:
#      price  timestamp  posted_date  deactivation_date  category  \
# 0  18000.0      85835       203003               2510         0
# 1  67000.0      86402       201493               1509         0
# 2  85000.0       1362        68293               1508         0
# 3  47000.0      14140        73582               3436         0
# 4   9000.0      31448        79694               3435         0
#
#    parent_category  location  geo_region  area  is_delivery_free  ...  \
# 0                0       127           1     4                 0  ...
# 1                0       120           1     4                 0  ...
# 2                0       120           1     4                 0  ...
# 3                0       119           1     4                 0  ...
# 4                0       119           1     4                 0  ...
#
#    is_verified  membership_level  member_since   user  Condition  Mileage  \
# 0            1                 2            86  52570          1  56000.0
# 1            1                 1            47  29644          1  56000.0
# 2            1                 1            47  29644          1  56000.0
# 3            0                 1            23  31390          0  56000.0
# 4            0                 1            23  31390          0  56000.0
#
#    Engine_capacity  Fuel_type  Brand  Model
# 0          56000.0          6    142    937
# 1          56000.0          6     96    937
# 2          56000.0          6    142    937
# 3          56000.0          6    142    937
# 4          56000.0          6    142    937
#
# [5 rows x 25 columns]

# %%
# # Define ColumnTransformer
# column_transformer = ColumnTransformer(
#     transformers=[
#         ('brand_n', OneHotEncoder(), ['Brand']),
#         ('model_n', OneHotEncoder(), ['Model'])
#     ],
#     remainder='passthrough'  # To keep the remaining columns
# )

# %%
# df1 = column_transformer.fit_transform(df)

# %%
# ecols = ct.get_feature_names_out()
# df = pd.DataFrame(df1,columns = ecols)

# %%
# df.head()

# %%
from sklearn.preprocessing import StandardScaler

# %%
df.head()
# Out:
#      price  timestamp  posted_date  deactivation_date  category  \
# 0  18000.0      85835       203003               2510         0
# 1  67000.0      86402       201493               1509         0
# 2  85000.0       1362        68293               1508         0
# 3  47000.0      14140        73582               3436         0
# 4   9000.0      31448        79694               3435         0
#
#    parent_category  location  geo_region  area  is_delivery_free  ...  \
# 0                0       127           1     4                 0  ...
# 1                0       120           1     4                 0  ...
# 2                0       120           1     4                 0  ...
# 3                0       119           1     4                 0  ...
# 4                0       119           1     4                 0  ...
#
#    is_verified  membership_level  member_since   user  Condition  Mileage  \
# 0            1                 2            86  52570          1  56000.0
# 1            1                 1            47  29644          1  56000.0
# 2            1                 1            47  29644          1  56000.0
# 3            0                 1            23  31390          0  56000.0
# 4            0                 1            23  31390          0  56000.0
#
#    Engine_capacity  Fuel_type  Brand  Model
# 0          56000.0          6    142    937
# 1          56000.0          6     96    937
# 2          56000.0          6    142    937
# 3          56000.0          6    142    937
# 4          56000.0          6    142    937
#
# [5 rows x 25 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
df.iloc[:,1:] = sc.fit_transform(df.iloc[:,1:])
# Out:
# C:\Users\ranu1\AppData\Local\Temp\ipykernel_10892\3697595479.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 0.93544796  0.95281559 -1.65202203 ... -1.69193388 -1.69199514
#  -1.69199514]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   df.iloc[:,1:] = sc.fit_transform(df.iloc[:,1:])
# C:\Users\ranu1\AppData\Local\Temp\ipykernel_10892\3697595479.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 1.06459627  1.04375727 -0.79449123 ...  1.70937711  1.70936331
#   1.70934951]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   df.iloc[:,1:] = sc.fit_transform(df.iloc[:,1:])
# C:\Users\ranu1\AppData\Local\Temp\ipykernel_10892\3697595479.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-1.69955219 -1.71323693 -1.71325061 ...  1.71446936  1.71448303
#   1.71444202]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   df.iloc[:,1:] = sc.fit_transform(df.iloc[:,1:])
# C:\Users\ranu1\AppData\Local\Temp\ipykernel_10892\3697595479.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-1.33004527 -1.33004527 -1.33004527 ...  1.03166937 -0.01798158
#   0.76925663]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   df.iloc[:,1:] = sc.fit_transform(df.iloc[:,1:])
# C:\Users\ranu1\AppData\Local\Temp\ipykernel_10892\3697595479.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 0.3944172   0.26456511  0.26456511 ... -1.21945883 -1.44206242
#   0.07906211]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   df.iloc[:,1:] = sc.fit_transform(df.iloc[:,1:])
# C:\Users\ranu1\AppData\Local\Temp\ipykernel_10892\3697595479.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.57921652 -0.57921652 -0.57921652 ... -0.57921652 -0.57921652
#   2.22930686]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   df.iloc[:,1:] = sc.fit_transform(df.iloc[:,1:])
# C:\Users\ranu1\AppData\Local\Temp\ipykernel_10892\3697595479.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.65823597 -0.65823597 -0.65823597 ... -0.65823597 -0.65823597
#  -1.24419888]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   df.iloc[:,1:] = sc.fit_transform(df.iloc[:,1:])
# C:\Users\ranu1\AppData\Local\Temp\ipykernel_10892\3697595479.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 1.28365224  1.28365224  1.28365224 ... -0.77902719  1.28365224
#  -0.77902719]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   df.iloc[:,1:] = sc.fit_transform(df.iloc[:,1:])
# C:\Users\ranu1\AppData\Local\Temp\ipykernel_10892\3697595479.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.01308038 -0.01308038 -0.01308038 ... -0.01308038 -0.01308038
#  -0.01308038]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   df.iloc[:,1:] = sc.fit_transform(df.iloc[:,1:])
# C:\Users\ranu1\AppData\Local\Temp\ipykernel_10892\3697595479.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.0073779 -0.0073779 -0.0073779 ... -0.0073779 -0.0073779 -0.0073779]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   df.iloc[:,1:] = sc.fit_transform(df.iloc[:,1:])
# C:\Users\ranu1\AppData\Local\Temp\ipykernel_10892\3697595479.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 1.69085303  1.69085303  1.69085303 ... -0.59141746 -0.59141746
#  -0.59141746]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:,1:] = sc.fit_transform(df.iloc[:,1:])
# C:\Users\ranu1\AppData\Local\Temp\ipykernel_10892\3697595479.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 1.46589667  0.35690775  0.35690775 ... -0.75208118  1.46589667
#  -0.75208118]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   df.iloc[:,1:] = sc.fit_transform(df.iloc[:,1:])
# C:\Users\ranu1\AppData\Local\Temp\ipykernel_10892\3697595479.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 2.73660541  0.97690701  0.97690701 ... -0.46694809 -0.33158667
#  -0.46694809]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   df.iloc[:,1:] = sc.fit_transform(df.iloc[:,1:])
# C:\Users\ranu1\AppData\Local\Temp\ipykernel_10892\3697595479.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 0.50870083 -0.49302687 -0.49302687 ...  0.96490945 -0.07290946
#  -1.27916858]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   df.iloc[:,1:] = sc.fit_transform(df.iloc[:,1:])
# C:\Users\ranu1\AppData\Local\Temp\ipykernel_10892\3697595479.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-1.09020061 -1.09020061 -1.09020061 ...  1.70501865  0.30740902
#   0.30740902]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   df.iloc[:,1:] = sc.fit_transform(df.iloc[:,1:])
# C:\Users\ranu1\AppData\Local\Temp\ipykernel_10892\3697595479.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 0.35984932  0.35984932  0.35984932 ...  0.35984932 -0.68493596
#   0.35984932]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   df.iloc[:,1:] = sc.fit_transform(df.iloc[:,1:])
# C:\Users\ranu1\AppData\Local\Temp\ipykernel_10892\3697595479.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1.02039287 0.08905852 1.02039287 ... 1.02039287 0.73694329 0.65595769]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   df.iloc[:,1:] = sc.fit_transform(df.iloc[:,1:])
# C:\Users\ranu1\AppData\Local\Temp\ipykernel_10892\3697595479.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.98777872 0.98777872 0.98777872 ... 0.98777872 0.13826094 0.4074497 ]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   df.iloc[:,1:] = sc.fit_transform(df.iloc[:,1:])

# %%
df.head()
# Out:
#      price  timestamp  posted_date  deactivation_date  category  \
# 0  18000.0   0.935448     1.064596          -1.699552 -1.330045
# 1  67000.0   0.952816     1.043757          -1.713237 -1.330045
# 2  85000.0  -1.652022    -0.794491          -1.713251 -1.330045
# 3  47000.0  -1.260623    -0.721500          -1.686893 -1.330045
# 4   9000.0  -0.730466    -0.637150          -1.686906 -1.330045
#
#    parent_category  location  geo_region      area  is_delivery_free  ...  \
# 0                0  0.394417   -0.579217 -0.658236                 0  ...
# 1                0  0.264565   -0.579217 -0.658236                 0  ...
# 2                0  0.264565   -0.579217 -0.658236                 0  ...
# 3                0  0.246015   -0.579217 -0.658236                 0  ...
# 4                0  0.246015   -0.579217 -0.658236                 0  ...
#
#    is_verified  membership_level  member_since      user  Condition   Mileage  \
# 0     1.690853          1.465897      2.736605  0.508701  -1.090201 -0.245042
# 1     1.690853          0.356908      0.976907 -0.493027  -1.090201 -0.245042
# 2     1.690853          0.356908      0.976907 -0.493027  -1.090201 -0.245042
# 3    -0.591417          0.356908     -0.105984 -0.416737  -2.487810 -0.245042
# 4    -0.591417          0.356908     -0.105984 -0.416737  -2.487810 -0.245042
#
#    Engine_capacity  Fuel_type     Brand     Model
# 0        -0.245042   0.359849  1.020393  0.987779
# 1        -0.245042   0.359849  0.089059  0.987779
# 2        -0.245042   0.359849  1.020393  0.987779
# 3        -0.245042   0.359849  1.020393  0.987779
# 4        -0.245042   0.359849  1.020393  0.987779
#
# [5 rows x 25 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

import statsmodels.api as sm

# %%
df.head()
# Out:
#      price  timestamp  posted_date  deactivation_date  category  \
# 0  18000.0   0.935448     1.064596          -1.699552 -1.330045
# 1  67000.0   0.952816     1.043757          -1.713237 -1.330045
# 2  85000.0  -1.652022    -0.794491          -1.713251 -1.330045
# 3  47000.0  -1.260623    -0.721500          -1.686893 -1.330045
# 4   9000.0  -0.730466    -0.637150          -1.686906 -1.330045
#
#    parent_category  location  geo_region      area  is_delivery_free  ...  \
# 0                0  0.394417   -0.579217 -0.658236                 0  ...
# 1                0  0.264565   -0.579217 -0.658236                 0  ...
# 2                0  0.264565   -0.579217 -0.658236                 0  ...
# 3                0  0.246015   -0.579217 -0.658236                 0  ...
# 4                0  0.246015   -0.579217 -0.658236                 0  ...
#
#    is_verified  membership_level  member_since      user  Condition   Mileage  \
# 0     1.690853          1.465897      2.736605  0.508701  -1.090201 -0.245042
# 1     1.690853          0.356908      0.976907 -0.493027  -1.090201 -0.245042
# 2     1.690853          0.356908      0.976907 -0.493027  -1.090201 -0.245042
# 3    -0.591417          0.356908     -0.105984 -0.416737  -2.487810 -0.245042
# 4    -0.591417          0.356908     -0.105984 -0.416737  -2.487810 -0.245042
#
#    Engine_capacity  Fuel_type     Brand     Model
# 0        -0.245042   0.359849  1.020393  0.987779
# 1        -0.245042   0.359849  0.089059  0.987779
# 2        -0.245042   0.359849  1.020393  0.987779
# 3        -0.245042   0.359849  1.020393  0.987779
# 4        -0.245042   0.359849  1.020393  0.987779
#
# [5 rows x 25 columns]

# %%
x_train,x_test,y_train,y_test = train_test_split(df.drop('price',axis=1),df['price'],test_size=0.2,random_state=8)

# %% [markdown]
# # Model 1

# %%
las = Lasso()
las.fit(x_train,y_train)
# Out:
# Lasso()

# %%
y_pred1 = las.predict(x_test)

# %%
las.coef_     #giving the coefficients of all the columns
# Out:
# array([ 1.71712890e+04, -4.23747135e+05,  3.74446167e+05,  2.89734835e+05,
#         0.00000000e+00, -2.41376966e+05, -9.40647879e+04, -1.57020980e+05,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  5.34204527e+05,
#         5.91284646e+04,  6.30039081e+04,  4.13395893e+05, -1.47381470e+05,
#        -1.75056734e+05,  6.04985752e+04,  7.13524026e+04, -1.25349240e+05,
#        -3.37848369e-09, -2.48131556e+06,  3.11442380e+03, -7.27369008e+05])

# %%
las.intercept_
# Out:
# 2045780.5204314918

# %%
cols = df.drop('price',axis=1).columns

# %%
naq = pd.Series(las.coef_,index=cols)

# %%
naq.plot(kind='barh')
# Out:
# <Axes: >

# %%
metrics.mean_squared_error(y_test,y_pred1)
# Out:
# 25142343880090.35

# %%
metrics.mean_absolute_error(y_test,y_pred1)
# Out:
# 1969895.26968333

# %%
metrics.r2_score(y_test,y_pred1)
# Out:
# 0.23709083659037633

# %%
naq
# Out:
# timestamp               1.717129e+04
# posted_date            -4.237471e+05
# deactivation_date       3.744462e+05
# category                2.897348e+05
# parent_category         0.000000e+00
# location               -2.413770e+05
# geo_region             -9.406479e+04
# area                   -1.570210e+05
# is_delivery_free        0.000000e+00
# is_doorstep_delivery    0.000000e+00
# is_dsd_applicable       0.000000e+00
# is_member               5.342045e+05
# is_authorized_dealer    5.912846e+04
# is_featured_member      6.300391e+04
# is_verified             4.133959e+05
# membership_level       -1.473815e+05
# member_since           -1.750567e+05
# user                    6.049858e+04
# Condition               7.135240e+04
# Mileage                -1.253492e+05
# Engine_capacity        -3.378484e-09
# Fuel_type              -2.481316e+06
# Brand                   3.114424e+03
# Model                  -7.273690e+05
# dtype: float64

# %%
coeffs = naq.abs().sort_values(ascending=False)

# %%
coeffs
# Out:
# Fuel_type               2.481316e+06
# Model                   7.273690e+05
# is_member               5.342045e+05
# posted_date             4.237471e+05
# is_verified             4.133959e+05
# deactivation_date       3.744462e+05
# category                2.897348e+05
# location                2.413770e+05
# member_since            1.750567e+05
# area                    1.570210e+05
# membership_level        1.473815e+05
# Mileage                 1.253492e+05
# geo_region              9.406479e+04
# Condition               7.135240e+04
# is_featured_member      6.300391e+04
# user                    6.049858e+04
# is_authorized_dealer    5.912846e+04
# timestamp               1.717129e+04
# Brand                   3.114424e+03
# Engine_capacity         3.378484e-09
# is_dsd_applicable       0.000000e+00
# is_doorstep_delivery    0.000000e+00
# is_delivery_free        0.000000e+00
# parent_category         0.000000e+00
# dtype: float64

# %%
selected_features = coeffs.iloc[:16].index.tolist()
selected_features
# Out:
# ['Fuel_type',
#  'Model',
#  'is_member',
#  'posted_date',
#  'is_verified',
#  'deactivation_date',
#  'category',
#  'location',
#  'member_since',
#  'area',
#  'membership_level',
#  'Mileage',
#  'geo_region',
#  'Condition',
#  'is_featured_member',
#  'user']

# %% [markdown]
# ## Now creating a new DF from the selected features to train our model

# %%
df1 = df[['Fuel_type',
 'Model',
 'is_member',
 'posted_date',
 'is_verified',
 'deactivation_date',
 'category',
 'location',
 'member_since',
 'area',
 'membership_level',
 'Mileage',
 'geo_region',
 'Condition',
 'is_featured_member',
 'user','price']]

# %%
df1.head()
# Out:
#    Fuel_type     Model  is_member  posted_date  is_verified  \
# 0   0.359849  0.987779   1.283652     1.064596     1.690853
# 1   0.359849  0.987779   1.283652     1.043757     1.690853
# 2   0.359849  0.987779   1.283652    -0.794491     1.690853
# 3   0.359849  0.987779   1.283652    -0.721500    -0.591417
# 4   0.359849  0.987779   1.283652    -0.637150    -0.591417
#
#    deactivation_date  category  location  member_since      area  \
# 0          -1.699552 -1.330045  0.394417      2.736605 -0.658236
# 1          -1.713237 -1.330045  0.264565      0.976907 -0.658236
# 2          -1.713251 -1.330045  0.264565      0.976907 -0.658236
# 3          -1.686893 -1.330045  0.246015     -0.105984 -0.658236
# 4          -1.686906 -1.330045  0.246015     -0.105984 -0.658236
#
#    membership_level   Mileage  geo_region  Condition  is_featured_member  \
# 0          1.465897 -0.245042   -0.579217  -1.090201           -0.007378
# 1          0.356908 -0.245042   -0.579217  -1.090201           -0.007378
# 2          0.356908 -0.245042   -0.579217  -1.090201           -0.007378
# 3          0.356908 -0.245042   -0.579217  -2.487810           -0.007378
# 4          0.356908 -0.245042   -0.579217  -2.487810           -0.007378
#
#        user    price
# 0  0.508701  18000.0
# 1 -0.493027  67000.0
# 2 -0.493027  85000.0
# 3 -0.416737  47000.0
# 4 -0.416737   9000.0

# %%
x_train,x_test,y_train,y_test = train_test_split(df1.drop('price',axis=1),df1['price'],test_size=0.2,random_state=42)

# %% [markdown]
# # Linear Regression

# %%
li = LinearRegression()
model = li.fit(x_train,y_train)

# %%
y_pred = model.predict(x_test)

# %%
metrics.mean_squared_error(y_test,y_pred)
# Out:
# 22703291459770.78

# %%
metrics.r2_score(y_test,y_pred)
# Out:
# 0.2544070912895874

# %%
metrics.mean_absolute_error(y_test,y_pred)
# Out:
# 1949870.7680063683

# %% [markdown]
# # OLS

# %%
model = sm.OLS(y_train,x_train).fit()

# %%
print(model.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  price   R-squared (uncentered):                   0.129
# Model:                            OLS   Adj. R-squared (uncentered):              0.129
# Method:                 Least Squares   F-statistic:                              1903.
# Date:                Mon, 08 Jul 2024   Prob (F-statistic):                        0.00
# Time:                        11:53:40   Log-Likelihood:                     -3.5465e+06
# No. Observations:              205767   AIC:                                  7.093e+06
# Df Residuals:                  205751   BIC:                                  7.093e+06
# Df Model:                          16
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Fuel_type          -2.478e+06   1.76e+04   -140.576      0.000   -2.51e+06   -2.44e+06
# Model              -7.481e+05   2.17e+04    -34.510      0.000   -7.91e+05   -7.06e+05
# is_member           5.548e+05   5.73e+04      9.687      0.000    4.43e+05    6.67e+05
# posted_date        -4.298e+05   3.58e+04    -11.994      0.000      -5e+05    -3.6e+05
# is_verified         4.196e+05   2.49e+04     16.881      0.000    3.71e+05    4.68e+05
# deactivation_date   3.729e+05   3.59e+04     10.399      0.000    3.03e+05    4.43e+05
# category            2.702e+05   2.37e+04     11.395      0.000    2.24e+05    3.17e+05
# location           -2.396e+05   1.68e+04    -14.280      0.000   -2.73e+05   -2.07e+05
# member_since       -1.742e+05   1.84e+04     -9.447      0.000    -2.1e+05   -1.38e+05
# area               -1.527e+05    1.8e+04     -8.472      0.000   -1.88e+05   -1.17e+05
# membership_level   -1.593e+05   5.54e+04     -2.876      0.004   -2.68e+05   -5.07e+04
# Mileage            -1.219e+05    1.7e+04     -7.188      0.000   -1.55e+05   -8.87e+04
# geo_region         -9.774e+04   1.78e+04     -5.492      0.000   -1.33e+05   -6.29e+04
# Condition           8.594e+04   1.89e+04      4.539      0.000    4.88e+04    1.23e+05
# is_featured_member  5.756e+04   1.58e+04      3.652      0.000    2.67e+04    8.84e+04
# user                5.802e+04   1.64e+04      3.545      0.000    2.59e+04    9.01e+04
# ==============================================================================
# Omnibus:                   879613.280   Durbin-Watson:                   1.844
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):    8244618213905.552
# Skew:                         126.230   Prob(JB):                         0.00
# Kurtosis:                   31012.063   Cond. No.                         9.01
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y_pred = model.predict(x_test)

# %%
metrics.mean_squared_error(y_test,y_pred)
# Out:
# 26816807857552.51

# %%
metrics.r2_score(y_test,y_pred)
# Out:
# 0.1193161657519991

# %%
metrics.mean_absolute_error(y_test,y_pred)
# Out:
# 2485862.383170345

# %% [markdown]
# ## OLS performs worse than Linear Regression

# %% [markdown]
# ### Hyper Parameter Tuning choosing only the appropriate columns

# %%
#parameters={'alpha' : [1,5,10,20,35,45,50,55,60,75,80,95,100]}
#lass = GridSearchCV(las,parameters,scoring='neg_mean_squared_error', cv=5)
#lass.fit(x_train,y_train)

# %%
#lass.best_params_
# Out:
# {'alpha': 10}

# %% [markdown]
# # Using Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV

# %%
rf = RandomForestRegressor(n_estimators=100, max_depth=None, min_samples_split=2,
                           min_samples_leaf=1, max_features='sqrt', random_state=42)

# %%
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_features='sqrt', random_state=42)

# %%
y_pred = rf.predict(x_test)
mse = metrics.mean_squared_error(y_test, y_pred)
print("Mean Squared Error (MSE):", mse)
# Out:
# Mean Squared Error (MSE): 6372201836380.593

# %%
r2 = metrics.r2_score(y_test, y_pred)
print("R-squared (R²) score:", r2)
# Out:
# R-squared (R²) score: 0.7907321715665978

# %%
#Section 2: User Segmentation

# %%
df1 = pd.read_csv(r"C:\Users\ranu1\Downloads\vehicles.csv")

# %%
df1.head()
# Out:
#                                             ad_title  \
# 0     Nissan Tiida Alternator  in Maharagama | ikman
# 1              Axio 165 Tail Light  in Kotte | ikman
# 2     Axio 165 / 161 Head light  in Kotte | ikman.lk
# 3   Vigo side step ( Foot board)  in Kottawa | ikman
# 4  Vigo Dickey Door Garnish Cover  in Kottawa | i...
#
#                                       ad_description details  \
# 0  **TISSA AUTO PARTS** Dealer of used Japanese m...     NaN
# 1  Imported from Japan \n\nRight side available \...     NaN
# 2  Imported from Japan \n\nAuto focus headlight a...     NaN
# 3  Hilux Vigo side step\nBrand New Thaiwan\nGood ...     NaN
# 4  Hilux Vigo ( 2005, 2009 ) dickey door garnish set     NaN
#
#                                                 slug  \
# 0         nissan-tiida-alternator-for-sale-colombo-3
# 1            axio-165-tail-light-for-sale-colombo-14
# 2           axio-165-161-head-light-for-sale-colombo
# 3         vigo-side-step-foot-board-for-sale-colombo
# 4  vigo-dickey-door-garnish-cover-for-sale-colombo-1
#
#                             title      type      price        timestamp  \
# 0         Nissan Tiida Alternator  for_sale  Rs 18,000  23 Feb 11:35 pm
# 1             Axio 165 Tail Light  for_sale  Rs 67,000   23 Feb 8:32 am
# 2       Axio 165 / 161 Head light  for_sale  Rs 85,000   01 Dec 8:27 pm
# 3    Vigo side step ( Foot board)  for_sale  Rs 47,000   04 Dec 2:47 pm
# 4  Vigo Dickey Door Garnish Cover  for_sale   Rs 9,000   08 Dec 9:28 am
#
#                  posted_date         deactivation_date  ...  \
# 0  2023-02-23T23:35:10+05:30  2022-05-30T17:13:04.000Z  ...
# 1  2023-02-23T08:32:44+05:30  2022-03-31T16:27:59.000Z  ...
# 2  2022-12-01T20:27:49+05:30  2022-03-31T14:03:57.000Z  ...
# 3  2022-12-04T14:47:27+05:30  2022-07-29T13:22:59.000Z  ...
# 4  2022-12-08T09:28:04+05:30  2022-07-29T12:55:44.000Z  ...
#
#   is_doorstep_delivery is_dsd_applicable is_member is_authorized_dealer  \
# 0                False             False      True                False
# 1                False             False      True                False
# 2                False             False      True                False
# 3                False             False      True                False
# 4                False             False      True                False
#
#   is_featured_member  is_verified  membership_level    member_since  \
# 0              False         True           premium  September 2019
# 1              False         True              plus       June 2018
# 2              False         True              plus       June 2018
# 3              False        False              plus   February 2017
# 4              False        False              plus   February 2017
#
#                                           properties  \
# 0  {'Condition': 'Reconditioned', 'Part or Access...
# 1  {'Condition': 'Reconditioned', 'Part or Access...
# 2  {'Condition': 'Reconditioned', 'Part or Access...
# 3  {'Condition': 'New', 'Part or Accessory Type':...
# 4  {'Condition': 'New', 'Part or Accessory Type':...
#
#                                                 user
# 0  a6681dea494390daa516a6d2bdcb36e08c318574a13413...
# 1  5d99b8e45a1bb318079da7a36392d9025e1644cb49ecbf...
# 2  5d99b8e45a1bb318079da7a36392d9025e1644cb49ecbf...
# 3  634d93e14a62d9de7b400ee3679ae1d5506f4252ff0580...
# 4  634d93e14a62d9de7b400ee3679ae1d5506f4252ff0580...
#
# [5 rows x 26 columns]

# %%
df1.isnull().sum()
# Out:
# ad_title                     0
# ad_description               7
# details                 103383
# slug                         0
# title                        0
# type                         0
# price                     3811
# timestamp                    6
# posted_date                  6
# deactivation_date            6
# category                     0
# parent_category              0
# location                     0
# geo_region                   0
# area                         0
# is_delivery_free             0
# is_doorstep_delivery         0
# is_dsd_applicable            0
# is_member                 9050
# is_authorized_dealer      9050
# is_featured_member        9050
# is_verified                  0
# membership_level             0
# member_since            150254
# properties                   0
# user                         0
# dtype: int64

# %%
df1.columns
# Out:
# Index(['ad_title', 'ad_description', 'details', 'slug', 'title', 'type',
#        'price', 'timestamp', 'posted_date', 'deactivation_date', 'category',
#        'parent_category', 'location', 'geo_region', 'area', 'is_delivery_free',
#        'is_doorstep_delivery', 'is_dsd_applicable', 'is_member',
#        'is_authorized_dealer', 'is_featured_member', 'is_verified',
#        'membership_level', 'member_since', 'properties', 'user'],
#       dtype='object')

# %%
df1 = df1.drop(['ad_title', 'ad_description', 'details', 'slug', 'title','properties'],axis=1)

# %%
df1.isnull().sum()
# Out:
# type                         0
# price                     3811
# timestamp                    6
# posted_date                  6
# deactivation_date            6
# category                     0
# parent_category              0
# location                     0
# geo_region                   0
# area                         0
# is_delivery_free             0
# is_doorstep_delivery         0
# is_dsd_applicable            0
# is_member                 9050
# is_authorized_dealer      9050
# is_featured_member        9050
# is_verified                  0
# membership_level             0
# member_since            150254
# user                         0
# dtype: int64

# %%
df1.dropna(subset=['timestamp','posted_date','deactivation_date'], inplace = True)

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='most_frequent')

# %%
df1[['is_member']] = imputer.fit_transform(df1[['is_member']])
df1[['is_authorized_dealer']] = imputer.fit_transform(df1[['is_authorized_dealer']])
df1[['is_featured_member']] = imputer.fit_transform(df1[['is_featured_member']])
df1[['member_since']] = imputer.fit_transform(df1[['member_since']])

# %%
df1.isnull().sum()
# Out:
# type                       0
# price                   3811
# timestamp                  0
# posted_date                0
# deactivation_date          0
# category                   0
# parent_category            0
# location                   0
# geo_region                 0
# area                       0
# is_delivery_free           0
# is_doorstep_delivery       0
# is_dsd_applicable          0
# is_member                  0
# is_authorized_dealer       0
# is_featured_member         0
# is_verified                0
# membership_level           0
# member_since               0
# user                       0
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# type                       0
# price                   3811
# timestamp                  0
# posted_date                0
# deactivation_date          0
# category                   0
# parent_category            0
# location                   0
# geo_region                 0
# area                       0
# is_delivery_free           0
# is_doorstep_delivery       0
# is_dsd_applicable          0
# is_member                  0
# is_authorized_dealer       0
# is_featured_member         0
# is_verified                0
# membership_level           0
# member_since               0
# user                       0
# dtype: int64

# %%
df1['price'] = df1['price'].astype(str)
df1 = df1[df1['price']!='Negotiable']
df1['price'] = df1['price'].apply(lambda x: x.replace('Rs ',''))
df1['price'] = df1['price'].apply(lambda x:x.replace(',',''))
df1['price'] = pd.to_numeric(df1['price'],errors='coerce')

# %%
from sklearn.impute import SimpleImputer
imputer1 = SimpleImputer(strategy='median')
imputer1.fit(df1[['price']])
# Out:
# SimpleImputer(strategy='median')

# %%
df1[['price']] = imputer1.transform(df1[['price']])

# %%
df1.tail()
# Out:
#             type      price        timestamp                posted_date  \
# 258883  for_sale  1030000.0  01 Apr 11:41 am  2023-04-01T11:41:50+05:30
# 258884  for_sale  3550000.0  30 Mar 10:10 am  2023-03-30T10:10:04+05:30
# 258885  for_sale    70000.0  01 Apr 11:41 am  2023-04-01T11:41:13+05:30
# 258886  for_sale  7250000.0  01 Apr 11:40 am  2023-04-01T11:40:57+05:30
# 258887  for_sale   135000.0  01 Apr 11:40 am  2023-04-01T11:40:56+05:30
#
#                deactivation_date    category parent_category       location  \
# 258883  2023-05-31T06:11:16.000Z        Cars        Vehicles    Jaffna City
# 258884  2023-05-29T04:36:57.000Z        Cars        Vehicles   Battaramulla
# 258885  2023-05-31T06:10:48.000Z     Rentals        Vehicles      Colombo 3
# 258886  2023-05-31T06:10:57.000Z        Cars        Vehicles  Boralesgamuwa
# 258887  2023-05-31T06:10:26.000Z  Motorbikes        Vehicles       Kekirawa
#
#        geo_region                                  area  is_delivery_free  \
# 258883      LK-41        {'id': 1605, 'name': 'Jaffna'}             False
# 258884      LK-11       {'id': 1506, 'name': 'Colombo'}             False
# 258885      LK-11       {'id': 1506, 'name': 'Colombo'}             False
# 258886      LK-11       {'id': 1506, 'name': 'Colombo'}             False
# 258887      LK-71  {'id': 1452, 'name': 'Anuradhapura'}             False
#
#         is_doorstep_delivery  is_dsd_applicable is_member  \
# 258883                 False              False     False
# 258884                 False              False     False
# 258885                 False              False     False
# 258886                 False              False      True
# 258887                 False              False     False
#
#        is_authorized_dealer is_featured_member  is_verified membership_level  \
# 258883                False              False        False             free
# 258884                False              False        False             free
# 258885                False              False        False             free
# 258886                False              False        False          premium
# 258887                False              False        False             free
#
#          member_since                                               user
# 258883  December 2016  48a910425b8f190b818a89d56b60a919c8b5297b0208ea...
# 258884  December 2016  c9b739e56cdac87b2a966a338eb8508c15dd977445751b...
# 258885  December 2016  c7bf4bbdbcd88d9d7f7c7b299c94e9e52091af2fd2888e...
# 258886  December 2019  7c6477247c19fa63845687656fee40702da46c9d184568...
# 258887  December 2016  250f50f6456508d02d1f94e93cf90bfe5659696d70e5d2...

# %%
from sklearn.preprocessing import LabelEncoder

# Assume df is your DataFrame
label_encoder = LabelEncoder()

for column in df1.columns:
    if df1[column].dtype == 'bool' or df1[column].dtype == 'object':
        df1[column] = label_encoder.fit_transform(df1[column])

print(df1.head())
# Out:
#    type    price  timestamp  posted_date  deactivation_date  category  \
# 0     0  18000.0      85835       203003               2510         0
# 1     0  67000.0      86402       201493               1509         0
# 2     0  85000.0       1362        68293               1508         0
# 3     0  47000.0      14140        73582               3436         0
# 4     0   9000.0      31448        79694               3435         0
#
#    parent_category  location  geo_region  area  is_delivery_free  \
# 0                0       127           1     4                 0
# 1                0       120           1     4                 0
# 2                0       120           1     4                 0
# 3                0       119           1     4                 0
# 4                0       119           1     4                 0
#
#    is_doorstep_delivery  is_dsd_applicable  is_member  is_authorized_dealer  \
# 0                     0                  0          1                     0
# 1                     0                  0          1                     0
# 2                     0                  0          1                     0
# 3                     0                  0          1                     0
# 4                     0                  0          1                     0
#
#    is_featured_member  is_verified  membership_level  member_since   user
# 0                   0            1                 2            86  52570
# 1                   0            1                 1            47  29644
# 2                   0            1                 1            47  29644
# 3                   0            0                 1            23  31390
# 4                   0            0                 1            23  31390

# %%
df1.tail()
# Out:
#         type      price  timestamp  posted_date  deactivation_date  category  \
# 258883     0  1030000.0         59       249725             252238         5
# 258884     0  3550000.0     109903       249643             252161         5
# 258885     0    70000.0         59       249724             252236         9
# 258886     0  7250000.0         57       249723             252237         5
# 258887     0   135000.0         57       249722             252234         8
#
#         parent_category  location  geo_region  area  is_delivery_free  \
# 258883                0        93           8     8                 0
# 258884                0        21           1     4                 0
# 258885                0        40           1     4                 0
# 258886                0        28           1     4                 0
# 258887                0       110          17     1                 0
#
#         is_doorstep_delivery  is_dsd_applicable  is_member  \
# 258883                     0                  0          0
# 258884                     0                  0          0
# 258885                     0                  0          0
# 258886                     0                  0          1
# 258887                     0                  0          0
#
#         is_authorized_dealer  is_featured_member  is_verified  \
# 258883                     0                   0            0
# 258884                     0                   0            0
# 258885                     0                   0            0
# 258886                     0                   0            0
# 258887                     0                   0            0
#
#         membership_level  member_since   user
# 258883                 0            15  22935
# 258884                 0            15  63632
# 258885                 0            15  63011
# 258886                 2            18  39259
# 258887                 0            15  11652

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
scaled_df = sc.fit_transform(df1)

# %%
df1.head()
# Out:
#    type    price  timestamp  posted_date  deactivation_date  category  \
# 0     0  18000.0      85835       203003               2510         0
# 1     0  67000.0      86402       201493               1509         0
# 2     0  85000.0       1362        68293               1508         0
# 3     0  47000.0      14140        73582               3436         0
# 4     0   9000.0      31448        79694               3435         0
#
#    parent_category  location  geo_region  area  is_delivery_free  \
# 0                0       127           1     4                 0
# 1                0       120           1     4                 0
# 2                0       120           1     4                 0
# 3                0       119           1     4                 0
# 4                0       119           1     4                 0
#
#    is_doorstep_delivery  is_dsd_applicable  is_member  is_authorized_dealer  \
# 0                     0                  0          1                     0
# 1                     0                  0          1                     0
# 2                     0                  0          1                     0
# 3                     0                  0          1                     0
# 4                     0                  0          1                     0
#
#    is_featured_member  is_verified  membership_level  member_since   user
# 0                   0            1                 2            86  52570
# 1                   0            1                 1            47  29644
# 2                   0            1                 1            47  29644
# 3                   0            0                 1            23  31390
# 4                   0            0                 1            23  31390

# %%
from sklearn.decomposition import PCA
# Apply PCA
pca = PCA(n_components=2)  # Reduce to 2 dimensions for visualization
principal_components = pca.fit_transform(scaled_df)

# Create a DataFrame with the principal components
pca_df = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2'])
print(pca_df.head())
# Out:
#         PC1       PC2
# 0  3.744637 -0.415312
# 1  2.666000 -0.471288
# 2  2.497046 -1.708932
# 3  1.193716 -1.630392
# 4  1.217047 -1.583489

# %%
# Visualize the explained variance
plt.figure(figsize=(8, 6))
plt.plot(range(1, len(pca.explained_variance_ratio_) + 1), pca.explained_variance_ratio_, marker='o')
plt.title('Explained Variance by Principal Components')
plt.xlabel('Number of Principal Components')
plt.ylabel('Explained Variance')
plt.show()

# %%
pca = PCA(n_components=2)
pca_data = pca.fit_transform(df1)

# %%
#Step 3: Clustering

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
data_for_clustering = pca_df
# Determine the optimal number of clusters using the Elbow Method
distortions = []
K = range(1, 11)
for k in K:
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(data_for_clustering)
    distortions.append(kmeans.inertia_)

# %%
# Plot the Elbow Method
plt.figure(figsize=(8, 6))
plt.plot(K, distortions, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.show()

# %%
# Apply K-means with the chosen number of clusters
optimal_clusters = 4  # Example: Choose based on the Elbow Method
kmeans = KMeans(n_clusters=optimal_clusters)
kmeans.fit(data_for_clustering)
df1['Cluster'] = kmeans.labels_

# %%
#Step 4 Cluster Analysis

# %%
# Add cluster labels to the original data
df1['Cluster'] = kmeans.labels_

# Group data by clusters and calculate mean values for each feature
cluster_summary = df1.groupby('Cluster').mean()

print(cluster_summary)
# Out:
#              type         price     timestamp    posted_date  \
# Cluster
# 0        0.005764  1.828713e+06  52960.918487   61509.125464
# 1        0.000000  2.625211e+06  56607.498444   81598.526110
# 2        0.008747  1.751593e+06  55502.138303  185956.008708
# 3        0.000022  2.329592e+06  57708.680926  189518.920552
#
#          deactivation_date  category  parent_category    location  geo_region  \
# Cluster
# 0             72321.790419  6.171008              0.0  104.093161    5.705120
# 1             57564.979916  3.245678              0.0  109.742055    1.876226
# 2            193424.496729  6.028783              0.0  104.081911    5.752513
# 3            189372.408852  3.474641              0.0  107.073684    1.992866
#
#              area  is_delivery_free  is_doorstep_delivery  is_dsd_applicable  \
# Cluster
# 0        8.517159               0.0                   0.0                0.0
# 1        5.378608               0.0                   0.0                0.0
# 2        8.520313               0.0                   0.0                0.0
# 3        5.561440               0.0                   0.0                0.0
#
#          is_member  is_authorized_dealer  is_featured_member  is_verified  \
# Cluster
# 0         0.005981              0.000000            0.000000     0.006053
# 1         0.988166              0.000729            0.000197     0.719470
# 2         0.010347              0.000000            0.000000     0.003961
# 3         0.993019              0.000152            0.000087     0.637321
#
#          membership_level  member_since          user
# Cluster
# 0                0.012794     17.633037  39934.071721
# 1                1.803489     38.701965  40838.051038
# 2                0.018578     17.807666  40784.781437
# 3                1.747238     37.229643  43059.467051

# %%
# Visualize clusters
plt.figure(figsize=(12, 8))
scatter = plt.scatter(data_for_clustering['PC1'], data_for_clustering['PC2'], c=df1['Cluster'], cmap='viridis', s=50, alpha=0.7, edgecolors='w', linewidth=0.5)
plt.title('User Clusters Visualization', fontsize=15)
plt.xlabel('Principal Component 1', fontsize=12)
plt.ylabel('Principal Component 2', fontsize=12)
plt.colorbar(label='Cluster')
plt.grid(True, linestyle='--', alpha=0.5)

# Add legend with cluster numbers
handles, labels = scatter.legend_elements(prop="colors", alpha=0.6)
legend = plt.legend(handles, [f'Cluster {i}' for i in range(optimal_clusters)], title="Clusters", loc="best")

plt.show()

# %%
#Section 3: Geographical Analysis of Demand and Supply

# %%
#importing the dataset
df = pd.read_csv(r"C:\Users\ranu1\Downloads\vehicles.csv")

# %%
#finding null values in the dataset
df.isnull().sum()
# Out:
# ad_title                     0
# ad_description               7
# details                 103383
# slug                         0
# title                        0
# type                         0
# price                     3811
# timestamp                    6
# posted_date                  6
# deactivation_date            6
# category                     0
# parent_category              0
# location                     0
# geo_region                   0
# area                         0
# is_delivery_free             0
# is_doorstep_delivery         0
# is_dsd_applicable            0
# is_member                 9050
# is_authorized_dealer      9050
# is_featured_member        9050
# is_verified                  0
# membership_level             0
# member_since            150254
# properties                   0
# user                         0
# dtype: int64

# %%
#selecting only those advertisements that are related to vehicles
df['category'].unique()
# Out:
# array(['Auto Parts & Accessories', 'Cars', 'Auto Services', 'Rentals',
#        'Vans', 'Lorries & Trucks', 'Three Wheelers', 'Motorbikes',
#        'Buses', 'Heavy Duty', 'Tractors', 'Bicycles',
#        'Boats & Water Transport'], dtype=object)

# %%
cols = ['Cars','Vans','Lorries & Trucks','Three Wheelers','Motorbikes','Buses','Heavy Duty','Tractors','Bicycles', 'Boats & Water Transport']

# %%
df = df[df['category'].isin(cols)]

# %%
df.head()
# Out:
#                                                ad_title  \
# 31    Ssang Yong Rexton Ultimate d/ca 2019  in Nugeg...
# 1349               Toyota CHR 2017  in Kohuwala | ikman
# 1701              Toyota Axio 2015  in Kohuwala | ikman
# 1702  Daihatsu Atrai Wagon Turbo 2016  in Kohuwala |...
# 1917     Mercedes Benz C180 2010  in Colombo 14 | ikman
#
#                                          ad_description     details  \
# 31    SSANGYONG REXTON D/cab,Aussie import,Model-Ult...        0 km
# 1349  GT\nUnregisterd\nVehicle can be seen at Dmmika...    9,000 km
# 1701  Unregistered \nAc/Ps/Pm, we also 2016 silver \...   24,000 km
# 1702  Unregistered \nPM/PS\n5 Door\nwe also Hijet An...   55,000 km
# 1917  Parking sensors\nMirror package\nSemi electric...  137,000 km
#
#                                                    slug  \
# 31    ssang-yong-rexton-ultimate-d-ca-2019-for-sale-...
# 1349               toyota-chr-2017-for-sale-colombo-498
# 1701             toyota-axio-2015-for-sale-colombo-1533
# 1702  daihatsu-atrai-wagon-turbo-2016-for-sale-colom...
# 1917       mercedes-benz-c180-2010-for-sale-colombo-217
#
#                                      title      type          price  \
# 31    Ssang Yong Rexton Ultimate d/ca 2019  for_sale  Rs 22,000,000
# 1349                       Toyota CHR 2017  for_sale  Rs 14,500,000
# 1701                      Toyota Axio 2015  for_sale  Rs 10,500,000
# 1702       Daihatsu Atrai Wagon Turbo 2016  for_sale   Rs 6,500,000
# 1917               Mercedes Benz C180 2010  for_sale  Rs 11,500,000
#
#            timestamp                posted_date         deactivation_date  \
# 31    25 Nov 2:29 pm  2022-11-25T14:29:55+05:30  2022-07-24T06:01:26.000Z
# 1349  12 Jan 9:26 am  2023-01-12T09:26:22+05:30  2022-04-12T06:41:36.000Z
# 1701  12 Jan 9:26 am  2023-01-12T09:26:29+05:30  2022-04-16T06:04:50.000Z
# 1702  09 Nov 2:33 pm  2022-11-09T14:33:53+05:30  2022-04-16T05:46:11.000Z
# 1917  14 Dec 4:17 pm  2022-12-14T16:17:03+05:30  2022-08-19T02:41:37.000Z
#
#       ... is_doorstep_delivery is_dsd_applicable is_member  \
# 31    ...                False             False      True
# 1349  ...                False             False      True
# 1701  ...                False             False      True
# 1702  ...                False             False      True
# 1917  ...                False             False      True
#
#      is_authorized_dealer is_featured_member  is_verified  membership_level  \
# 31                  False              False         True              plus
# 1349                False              False         True           premium
# 1701                False              False         True           premium
# 1702                False              False         True              plus
# 1917                False              False         True              plus
#
#        member_since                                         properties  \
# 31        July 2020  {'Brand': 'Ssang Yong', 'Model': 'Rexton', 'Tr...
# 1349  December 2015  {'Brand': 'Toyota', 'Model': 'CHR', 'Year of M...
# 1701  December 2015  {'Brand': 'Toyota', 'Model': 'Axio', 'Trim / E...
# 1702  December 2015  {'Brand': 'Daihatsu', 'Model': 'Atrai Wagon', ...
# 1917     April 2018  {'Brand': 'Mercedes Benz', 'Model': 'C180', 'Y...
#
#                                                    user
# 31    f5d27a3e26a293ffaacde64ecda5f5eb2e51fc212189d2...
# 1349  a5cd12de59a8e3e14f4772ed7fa370f4b6850e0be24425...
# 1701  a5cd12de59a8e3e14f4772ed7fa370f4b6850e0be24425...
# 1702  a5cd12de59a8e3e14f4772ed7fa370f4b6850e0be24425...
# 1917  5e2c4aef554936c221a6318bbc86e9db5b39da13b4d1c9...
#
# [5 rows x 26 columns]

# %%
#name of the columns in the dataset
df.columns
# Out:
# Index(['ad_title', 'ad_description', 'details', 'slug', 'title', 'type',
#        'price', 'timestamp', 'posted_date', 'deactivation_date', 'category',
#        'parent_category', 'location', 'geo_region', 'area', 'is_delivery_free',
#        'is_doorstep_delivery', 'is_dsd_applicable', 'is_member',
#        'is_authorized_dealer', 'is_featured_member', 'is_verified',
#        'membership_level', 'member_since', 'properties', 'user'],
#       dtype='object')

# %%
#selecting columns related to geography or time
df = df[['title','posted_date','category','area']]

# %%
#data types of different columns in the dataset
df.dtypes
# Out:
# title          object
# posted_date    object
# category       object
# area           object
# dtype: object

# %%
df.head()
# Out:
#                                      title                posted_date  \
# 31    Ssang Yong Rexton Ultimate d/ca 2019  2022-11-25T14:29:55+05:30
# 1349                       Toyota CHR 2017  2023-01-12T09:26:22+05:30
# 1701                      Toyota Axio 2015  2023-01-12T09:26:29+05:30
# 1702       Daihatsu Atrai Wagon Turbo 2016  2022-11-09T14:33:53+05:30
# 1917               Mercedes Benz C180 2010  2022-12-14T16:17:03+05:30
#
#      category                             area
# 31       Cars  {'id': 1506, 'name': 'Colombo'}
# 1349     Cars  {'id': 1506, 'name': 'Colombo'}
# 1701     Cars  {'id': 1506, 'name': 'Colombo'}
# 1702     Cars  {'id': 1506, 'name': 'Colombo'}
# 1917     Cars  {'id': 1506, 'name': 'Colombo'}

# %%
#splitting the area column into location
import ast
dict_df = df['area'].apply(pd.Series)

# %%
name = []
for i in range(dict_df.shape[0]):
    dict_converted = ast.literal_eval(dict_df.iloc[i][0])
    name.append(dict_converted['name'])

df['name']=name

# %%
df = df.drop('area',axis=1)

# %%
import matplotlib.pyplot as plt

# %%
#Visualize the distribution of advertisements across different regions.
category_counts = df['name'].value_counts()
category_counts.plot(kind='bar', figsize=(8, 6))
plt.title('Geographical Distribution')
plt.xlabel('Area')
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.show()

# %%
#Identify regions with high demand and supply

# %%
top_categories = category_counts.head(5)

# %%
other_count = category_counts.sum() - top_categories.sum()
top_categories['Others'] = other_count

# %%
plt.figure(figsize=(8, 6))
plt.pie(top_categories, labels=top_categories.index, autopct='%1.1f%%', startangle=140)
plt.title('Top Five Categories vs Others')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
#most of the advertisements comes from two cities in Sri Lanka that is colombo and Gampha as shown in the pie chart.
#they have a total of 58.2% share of the total advertisements.

#rest all the cities dont have much advertisements from their region as compared to the top two cities.
#all the other cities have a share of 41.8% of the total advertisements.

# %%
#Temporal Analysis

# %%
#Analyze how demand and supply vary over time in different regions

# %%
#converting the posted date into a suitable format
df['posted_date'] = pd.to_datetime(df['posted_date'])

# %%
df['date'] = df['posted_date'].dt.date

# %%
#preparing data for region wise visualization
df_colombo = df[df['name']=='Colombo']

# %%
category_counts = df_colombo['date'].value_counts()

# %%
category_counts = category_counts.sort_index()

# %%
category_counts
# Out:
# date
# 2022-09-06      2
# 2022-09-09      1
# 2022-09-14      1
# 2022-09-16      2
# 2022-09-19      2
#              ...
# 2023-03-29     25
# 2023-03-30     13
# 2023-03-31     18
# 2023-04-01    291
# 2023-04-02     17
# Name: count, Length: 184, dtype: int64

# %%
plt.figure(figsize=(15,8))
category_counts.plot()
plt.grid()
plt.title("Frequency of advertisements in colombo")
plt.xlabel("Time")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#preparing data for region wise visualization
df_gampaha = df[df['name']=='Gampaha']

# %%
category_counts1 = df_gampaha['date'].value_counts()

# %%
category_counts1 = category_counts1.sort_index()

# %%
plt.figure(figsize=(15,8))
category_counts1.plot()
plt.grid()
plt.title("Frequency of advertisements in gampha")
plt.xlabel("Time")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#Identify any seasonal trends or patterns.

# %%
category_counts2 = df['date'].value_counts()

# %%
category_counts2 = category_counts2.sort_index()

# %%
plt.figure(figsize=(15,8))
category_counts2.plot()
plt.grid()
plt.title("Frequency of advertisements overall")
plt.xlabel("Time")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# the above visualization shows that there is a dip in advertisement after every two months,
#first in october, then in december, then in february and then in april

# %%
#Model

# %%
#importing the dataset
df = pd.read_csv(r"C:\Users\ranu1\Downloads\vehicles.csv")

# %%
#choosing the columns that are required for the model
df=df[['area','posted_date','price']]

# %%
dict_df = df['area'].apply(pd.Series)

# %%
name = []
for i in range(dict_df.shape[0]):
    dict_converted = ast.literal_eval(dict_df.iloc[i][0])
    name.append(dict_converted['name'])

df['name']=name

# %%
df = df.drop('area',axis=1)

# %%
df['posted_date'] = pd.to_datetime(df['posted_date'])

# %%
df['month'] = df['posted_date'].dt.month

# %%
df = df.drop('posted_date',axis=1)

# %%
df['price'] = df['price'].astype(str)
df['price'] = df['price'].apply(lambda x: x.replace('Rs ',''))
df['price'] = df['price'].apply(lambda x: x.replace(',',''))
df['price'] = pd.to_numeric(df['price'],errors='coerce')

# %%
df.isnull().sum()
# Out:
# price    5484
# name        0
# month       6
# dtype: int64

# %%
#dropping null values from the price and month column
df = df.dropna(subset=['price'])
df = df.dropna(subset=['month'])

# %%
df.dtypes
# Out:
# price    float64
# name      object
# month    float64
# dtype: object

# %%
#encoding the region names in the dataset using label encoder
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

# %%
df['name'] = label_encoder.fit_transform(df['name'])

# %%
#making the model for regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
X = df.iloc[:,1:]
Y = df.iloc[:,0]

# %%
#splitting the data into train and test data
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
#the linear regression model
model = LinearRegression()

# %%
model.fit(X_train, Y_train)
y_pred = model.predict(X_test)

# %%
#evaluation metrics
mse = mean_squared_error(Y_test, y_pred)
r2 = r2_score(Y_test, y_pred)

# %%
print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 49959797292412.13
# R-squared: 0.004164505292644005

# %%
#insights
#there is a dip in advertisements in every two months
#gampha and colombo contributes most to the number of advertisements.

# %%
#recommendations
#keep a bi-monthly sale in posting advertisements so that the dip in advertisements is less
